# %%
import tensorflow as tf
from tensorflow.keras.layers import Input,Dense
from tensorflow.keras.models import Sequential

# %%
(X_train,y_train),(X_test,y_test)=tf.keras.datasets.mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %%
if len(X_train.shape) == 3:  # means grayscale images like MNIST
    X_train = X_train[..., None]   # add channel dimension → (60000,28,28,1)
    X_test  = X_test[..., None]

# %%
TARGET_SIZE = (28, 28)

if X_train.shape[1:3]!=TARGET_SIZE:
    print("Resizing images to 28x28")
    X_train = tf.image.resize(X_train, TARGET_SIZE)
    X_test = tf.image.resize(X_test, TARGET_SIZE)
else:
    print("Images already 28x28 So no resizing needed.")
# Out:
# Images already 28x28 So no resizing needed.

# %%
X_train.dtype
# Out:
# dtype('uint8')

# %%
X_train=X_train/255

# %%
X_train.dtype
# Out:
# dtype('float64')

# %%
X_train=X_train.reshape(-1,784)

# %%
x1.shape
# Out:
# (60000, 784)
